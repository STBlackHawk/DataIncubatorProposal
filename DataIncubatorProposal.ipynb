# %% [markdown]
# # Personality prediction using Online Social Networks digital footprint

# %%
print("Two data exploratory plots from PsychoFlickr dataset")
# Out:
# Two data exploratory plots from PsychoFlickr dataset

# %%
print("First plot shows distribution of each color feature for photos posted by each user")
# Out:
# First plot shows distribution of each color featur posted by each user

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.style.use('bmh')


data = pd.read_csv("DataExploratory.csv")

# %%
data.head()
# Out:
#        UserName  is_gray_scale  H_360_mean  S_100_mean  V_100_mean          P  \
# 0  10024349@N08              0   94.103625   38.734213   49.916523  42.963928
# 1  10276398@N02              0  109.029416   27.798435   47.707091  39.033549
# 2  11135829@N03              0  102.091383   34.160322   41.660866  36.261269
# 3  13655984@N08              0   89.618626   37.550748   47.998999  41.380474
# 4  13796992@N03              0  101.105919   32.314715   53.582011  44.080825
#
#           A          D  H_360_std  S_100_std     ...       H12_Spring_Green  \
# 0  7.766405 -25.541610  60.782935  22.139344     ...               0.004545
# 1  1.889863 -27.361890  79.403283  16.820802     ...               0.014611
# 2  7.581324 -20.730956  81.049605  22.763469     ...               0.022388
# 3  7.650759 -24.463000  87.940723  24.583078     ...               0.013578
# 4  2.778406 -30.381619  79.810273  22.119312     ...               0.034043
#
# ...

# %%
dataExp = data.drop
data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
print("Second Plot shows the correlation between features in these photos ")
# Out:
# Second Plot shows the correlation between features in these photos

# %%
corr = data.corr() 
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);
